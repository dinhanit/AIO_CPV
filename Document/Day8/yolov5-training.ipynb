# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 3.56 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.
# /kaggle/working/yolov5

# %%
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /kaggle/working/yolov5

# %%
# to display images
from IPython.display import Image, clear_output
import torch
from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 5016.7/8062.4 GB disk)

# %%
# configure .yaml file to guide the model for training
yaml_text = """train: /kaggle/input/traffic-detection-project/train/images
val: /kaggle/input/traffic-detection-project/valid/images
test: /kaggle/input/traffic-detection-project/test/test/images

nc: 5
names: ['bicycle', 'bus', 'car', 'motorbike', 'person']"""

with open("data/data.yaml", 'w') as file:
    file.write(yaml_text)

# %cat data/data.yaml
# Out:
# train: /kaggle/input/traffic-detection-project/train/images
# val: /kaggle/input/traffic-detection-project/valid/images
# test: /kaggle/input/traffic-detection-project/test/test/images
#
# nc: 5
# names: ['bicycle', 'bus', 'car', 'motorbike', 'person']

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate models/custom_yolov5s.yaml
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
#
# # Parameters
# nc: 5  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# we are going to using pre-trained weights from yolov5.pt model
from datetime import datetime
start = datetime.now()
# !python train.py --img 448 --batch 32 --epochs 20 --data data/data.yaml --cfg models/custom_yolov5s.yaml --weights yolov5s.pt --name yolov5s_results  --cache
end = datetime.now()
# Out:
# train: weights=yolov5s.pt, cfg=models/custom_yolov5s.yaml, data=data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=32, imgsz=448, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 77.5MB/s]
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     26970  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 214 layers, 7033114 parameters, 7033114 gradients, 16.0 GFLOPs
#
# Transferred 342/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/input/traffic-detection-project/train/labels... 5805 ima
# train: WARNING ⚠️ Cache directory /kaggle/input/traffic-detection-project/train is not writeable: [Errno 30] Read-only file system: '/kaggle/input/traffic-detection-project/train/labels.cache.npy'
# train: Caching images (3.3GB ram): 100%|██████████| 5805/5805 [00:47<00:00, 122.
# val: Scanning /kaggle/input/traffic-detection-project/valid/labels... 549 images
# val: WARNING ⚠️ Cache directory /kaggle/input/traffic-detection-project/valid is not writeable: [Errno 30] Read-only file system: '/kaggle/input/traffic-detection-project/valid/labels.cache.npy'
# val: Caching images (0.3GB ram): 100%|██████████| 549/549 [00:06<00:00, 83.84it/
#
# AutoAnchor: 4.60 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 448 train, 448 val
# Using 1 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/19      1.91G    0.08573    0.06148    0.02982        257        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.542      0.236      0.213     0.0927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19      2.74G    0.05921    0.05641    0.01772        174        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.423      0.475      0.418      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19      2.74G    0.05421    0.05307    0.01363        226        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.647      0.603      0.608      0.321
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19      2.74G    0.04719    0.05027   0.009386        187        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.755      0.676      0.744      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19      2.74G    0.04315    0.04887   0.007013        242        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.791      0.707      0.778      0.475
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19      2.74G    0.04038    0.04815   0.005886        198        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.816      0.748      0.819        0.5
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19      2.74G    0.03829    0.04587   0.005148        289        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.839       0.75      0.823      0.512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/19      2.74G    0.03695    0.04569   0.004825        153        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.822      0.774      0.832       0.53
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19      2.74G    0.03554    0.04477   0.004431        194        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270       0.85      0.792      0.844       0.54
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19      2.74G    0.03443    0.04411   0.003938        200        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.836      0.801       0.85      0.552
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19      2.74G    0.03331    0.04319   0.003704        156        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.854      0.799       0.86      0.557
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19      2.74G    0.03271    0.04307    0.00356        224        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.872      0.815       0.87      0.562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19      2.74G    0.03186    0.04161    0.00337        230        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.872       0.82      0.873      0.577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19      2.74G    0.03125    0.04122   0.003215        372        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.873      0.822      0.875      0.577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19      2.74G    0.03037    0.04021   0.002927        138        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.871      0.822       0.88      0.583
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19      2.74G    0.02985    0.03982    0.00282        249        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270        0.9      0.815      0.884       0.59
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19      2.74G     0.0294    0.03987   0.002698        385        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.888      0.834      0.887      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19      2.74G    0.02875    0.03953   0.002534        215        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.888      0.837       0.89      0.605
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/19      2.74G    0.02852    0.03838   0.002416        214        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.901      0.833      0.894      0.608
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19      2.74G    0.02818    0.03844   0.002391        194        448: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.886      0.849      0.894      0.614
#
# 20 epochs completed in 0.431 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.4MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        549       6270      0.886      0.848      0.894      0.614
#                bicycle        549        250      0.924      0.884      0.912      0.667
#                    bus        549        108      0.923      0.926       0.96       0.81
#                    car        549       3842      0.903      0.919      0.955      0.713
#              motorbike        549       1238      0.886      0.785      0.853      0.488
#                 person        549        832      0.795      0.728      0.791      0.393
# Results saved to runs/train/yolov5s_results

# %%
print("Runtime =",end-start)
# Out:
# Runtime = 0:32:27.188875

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('runs/train/yolov5s_results/train_batch0.jpg')
plt.figure(figsize=(20,15))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !python detect.py --source /kaggle/input/traffic-detection-project/test/images/ --weight runs/train/yolov5s_results/weights/best.pt --name expTestImage --conf 0.4
# Out:
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/kaggle/input/traffic-detection-project/test/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1000_png_jpg.rf.7179a0df58ad6448028bc5bc21dca41e.jpg: 640x640 2 bicycles, 13 cars, 1 motorbike, 1 person, 11.5ms
# image 2/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1095_png_jpg.rf.4d9f0370f1c09fb2a1d1666b155911e3.jpg: 640x640 1 bicycle, 16 cars, 3 motorbikes, 11.5ms
# image 3/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1100_png_jpg.rf.8b7574e1c4f3fd7b654c2a693404fd2d.jpg: 640x640 1 bicycle, 13 cars, 1 motorbike, 11.5ms
# image 4/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1240_png_jpg.rf.7e110b54d205ef0537ddc5dec81a79c2.jpg: 640x640 12 cars, 4 motorbikes, 11.6ms
# image 5/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1540_png_jpg.rf.b8ea6dd9130d82a3b6163bc3aaa823d3.jpg: 640x640 11 cars, 1 motorbike, 11.5ms
# image 6/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-1680_png_jpg.rf.fede1a51e422cc8fd628a4846615f65f.jpg: 640x640 14 cars, 3 motorbikes, 11.5ms
# image 7/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2105_png_jpg.rf.913b43f78d50d1ac51dcf3e43cc7da2b.jpg: 640x640 16 cars, 1 motorbike, 11.5ms
# image 8/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2125_png_jpg.rf.7ded3baa4a5760fe91f32e3dc0946b61.jpg: 640x640 1 bicycle, 17 cars, 3 motorbikes, 11.5ms
# image 9/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2250_png_jpg.rf.03ef2afb1ddf6d6fb42c62429ebbcea1.jpg: 640x640 12 cars, 3 motorbikes, 1 person, 11.5ms
# image 10/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2420_png_jpg.rf.12949ad5e139564e761cd26f2cd07f3c.jpg: 640x640 9 cars, 3 motorbikes, 11.5ms
# image 11/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2555_png_jpg.rf.e8fe552acc205329ac459d1087eb0637.jpg: 640x640 9 cars, 6 motorbikes, 1 person, 11.5ms
# image 12/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2670_png_jpg.rf.1287a75cc98666be54dfa494d7b2bfe8.jpg: 640x640 15 cars, 4 motorbikes, 11.5ms
# image 13/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2670_png_jpg.rf.60530a426ae98c3e8e6ffcad678cfdae.jpg: 640x640 14 cars, 3 motorbikes, 1 person, 11.5ms
# image 14/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2680_png_jpg.rf.305f12470094eb2510b876de1b5f8eb4.jpg: 640x640 13 cars, 4 motorbikes, 1 person, 11.5ms
# image 15/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-2995_png_jpg.rf.2fa2f60b9d1c1250287a03624c83817b.jpg: 640x640 11 cars, 4 motorbikes, 11.5ms
# image 16/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3125_png_jpg.rf.c928762f63b976739588cd27f57fcede.jpg: 640x640 14 cars, 5 motorbikes, 1 person, 11.5ms
# image 17/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3275_png_jpg.rf.77be8ec5a4c83e355c850ea89764c192.jpg: 640x640 11 cars, 4 motorbikes, 1 person, 11.5ms
# image 18/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3390_png_jpg.rf.e162de23d695e4152f1d15c07646418e.jpg: 640x640 1 bicycle, 17 cars, 4 motorbikes, 11.5ms
# image 19/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3415_png_jpg.rf.27d07c6cc10c50b17db86bb3cf862508.jpg: 640x640 2 bicycles, 15 cars, 7 motorbikes, 11.5ms
# image 20/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3535_png_jpg.rf.6e0b3ad91b2b02914b2d96894b05d7ca.jpg: 640x640 16 cars, 5 motorbikes, 11.5ms
# image 21/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3565_png_jpg.rf.a8e3ff61869acbaab7d4554782ef6c0b.jpg: 640x640 1 bicycle, 11 cars, 1 motorbike, 11.5ms
# image 22/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3820_png_jpg.rf.6e751af22bf6357373f1e31a064b0a9f.jpg: 640x640 14 cars, 2 motorbikes, 11.5ms
# image 23/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3840_png_jpg.rf.e81264f835d8c15a3d578aa0554a9975.jpg: 640x640 1 bicycle, 16 cars, 6 motorbikes, 11.5ms
# image 24/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-3860_png_jpg.rf.ca4146458524106c60359a59d42080b4.jpg: 640x640 1 bicycle, 12 cars, 6 motorbikes, 11.5ms
# image 25/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4120_png_jpg.rf.d4fd0b97f992f9de887c70a97dad5d8f.jpg: 640x640 14 cars, 3 motorbikes, 11.5ms
# image 26/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4130_png_jpg.rf.4a11f5840001e2dafed224d41a79b33c.jpg: 640x640 10 cars, 4 motorbikes, 11.5ms
# image 27/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4150_png_jpg.rf.0c2a8b2a9966fead3a0fc8f4d560719f.jpg: 640x640 8 cars, 4 motorbikes, 11.5ms
# image 28/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4255_png_jpg.rf.1aaeafcaa45d001401fd35bb2c7788ea.jpg: 640x640 18 cars, 2 motorbikes, 11.5ms
# image 29/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4400_png_jpg.rf.71193dbc426e26320a25cfb67e7e5233.jpg: 640x640 1 bicycle, 12 cars, 4 motorbikes, 1 person, 11.5ms
# image 30/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4420_png_jpg.rf.426b3003764408929230fab15285af66.jpg: 640x640 1 bicycle, 14 cars, 1 motorbike, 11.5ms
# image 31/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4540_png_jpg.rf.0a1d526d5508f4c7fe815c356babea4d.jpg: 640x640 12 cars, 7 motorbikes, 1 person, 11.5ms
# image 32/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4570_png_jpg.rf.da57386c53c9e7b758754e132e54a41d.jpg: 640x640 12 cars, 5 motorbikes, 11.5ms
# image 33/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4725_png_jpg.rf.4f13138d101d94e78ca94dd53bb4779b.jpg: 640x640 12 cars, 2 motorbikes, 11.5ms
# image 34/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4850_png_jpg.rf.465a57fdb61c7b46531176ad00381431.jpg: 640x640 12 cars, 6 motorbikes, 1 person, 11.5ms
# image 35/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4855_png_jpg.rf.f176d5307d277d914f010da8afaeb1c8.jpg: 640x640 11 cars, 4 motorbikes, 11.5ms
# image 36/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-4980_png_jpg.rf.12a1415ecb01eb7dc9e3045f0ff5a669.jpg: 640x640 16 cars, 5 motorbikes, 11.5ms
# image 37/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-5145_png_jpg.rf.3f1acd9087fddc94ce2b2c298cb60040.jpg: 640x640 1 bus, 13 cars, 5 motorbikes, 11.5ms
# image 38/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-5160_png_jpg.rf.a31f40322368dfb1379bd3534859ae68.jpg: 640x640 1 bus, 7 cars, 1 person, 11.5ms
# image 39/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-5280_png_jpg.rf.ef5cf76f24a11e3776a71203138f540d.jpg: 640x640 12 cars, 5 motorbikes, 1 person, 11.5ms
# image 40/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-5305_png_jpg.rf.b2f788568b4c710f18a1c297d9e2c086.jpg: 640x640 9 cars, 6 motorbikes, 11.5ms
# image 41/279 /kaggle/input/traffic-detection-project/test/images/aguanambi-5425_png_jpg.rf.14d5886ee52334426d7f89d58c2de516.jpg: 640x640 12 cars, 4 motorbikes, 1 person, 11.5ms
# image 42/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10005_png_jpg.rf.7825d1d05d59748c0f60f3de68a936bb.jpg: 640x640 3 cars, 5 motorbikes, 11.5ms
# image 43/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10015_png_jpg.rf.abb1bccc351dd4e0ee5a7ee0f41bcae8.jpg: 640x640 4 cars, 5 motorbikes, 11.5ms
# image 44/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10050_png_jpg.rf.2d145f0661410125bf58d203630d6fa3.jpg: 640x640 2 cars, 6 motorbikes, 11.6ms
# image 45/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10055_png_jpg.rf.75991e9ec51b134e7d1296d7775e8e0f.jpg: 640x640 3 cars, 4 motorbikes, 11.5ms
# image 46/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10110_png_jpg.rf.a5602c76417d103234fc3a3af6a005c8.jpg: 640x640 4 cars, 5 motorbikes, 11.5ms
# image 47/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10155_png_jpg.rf.cd933d18c41046baa122d9fb6e768179.jpg: 640x640 2 cars, 4 motorbikes, 11.6ms
# image 48/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10270_png_jpg.rf.b23a8859382f6e08ec767fe5934ce5e4.jpg: 640x640 1 car, 3 motorbikes, 11.5ms
# image 49/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10370_png_jpg.rf.0480ed5a0843bb80f842274c85b96ce4.jpg: 640x640 1 bicycle, 5 cars, 2 motorbikes, 11.6ms
# image 50/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10375_png_jpg.rf.558a5baa30854f83b5c03dd0b22a24d3.jpg: 640x640 1 bicycle, 5 cars, 11.5ms
# image 51/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10395_png_jpg.rf.4dc62bdef45bf6d71c7fe52a00e189da.jpg: 640x640 1 bicycle, 3 cars, 2 motorbikes, 11.5ms
# image 52/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10415_png_jpg.rf.ad5eb833b88c0f3e302c20f1f6fc32fb.jpg: 640x640 1 bicycle, 4 cars, 4 motorbikes, 1 person, 11.5ms
# image 53/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10435_png_jpg.rf.b30c89929859a5d03cc961f5b345390c.jpg: 640x640 2 bicycles, 1 car, 4 motorbikes, 11.5ms
# image 54/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10440_png_jpg.rf.ca83fe6066595a1f3ff80757a908d189.jpg: 640x640 1 bicycle, 2 cars, 5 motorbikes, 1 person, 11.6ms
# image 55/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1045_png_jpg.rf.a4819b54dede09cef62664156b2e767b.jpg: 640x640 1 bus, 4 cars, 1 motorbike, 11.5ms
# image 56/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10495_png_jpg.rf.126cf8442bcbe8880c7c10958c36f8da.jpg: 640x640 2 bicycles, 2 cars, 3 motorbikes, 1 person, 11.5ms
# image 57/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10505_png_jpg.rf.fdecaeab0dfbdb686fd11aefc7ab74e7.jpg: 640x640 1 bicycle, 6 cars, 1 motorbike, 11.5ms
# image 58/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1055_png_jpg.rf.3fc8ea777b5ce1ca691ed0ba918e235f.jpg: 640x640 4 cars, 11.5ms
# image 59/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10565_png_jpg.rf.d6b0384f52f30c7b07536cd36def88e4.jpg: 640x640 1 bicycle, 1 car, 1 motorbike, 11.5ms
# image 60/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10580_png_jpg.rf.bc97a488d81f01f82e0d25b6cf1dc930.jpg: 640x640 1 bicycle, 2 cars, 1 motorbike, 11.5ms
# image 61/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10710_png_jpg.rf.acb2b8b2da38205c313e954d051285ae.jpg: 640x640 1 bicycle, 3 cars, 3 motorbikes, 11.5ms
# image 62/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1085_png_jpg.rf.2140c135f44f45d103ff6c371a62d35e.jpg: 640x640 1 car, 2 motorbikes, 11.5ms
# image 63/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10965_png_jpg.rf.bc89fbd399c8f3239dc7735f9bbca90c.jpg: 640x640 1 bicycle, 3 cars, 1 motorbike, 11.5ms
# image 64/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-10975_png_jpg.rf.f39f7653f6f687c8dcf712fa83144b94.jpg: 640x640 1 bicycle, 4 cars, 2 motorbikes, 11.5ms
# image 65/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11010_png_jpg.rf.2a7bef22e0fe04d1d315ea4d595df1c2.jpg: 640x640 1 bicycle, 1 car, 2 motorbikes, 11.6ms
# image 66/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11030_png_jpg.rf.5abd8287f8cc969e0644f73cf40142d5.jpg: 640x640 1 bicycle, 2 cars, 1 motorbike, 11.6ms
# image 67/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11110_png_jpg.rf.e5383fd1bacdd9c0807cb8183d569a5a.jpg: 640x640 1 bicycle, 4 cars, 1 motorbike, 11.5ms
# image 68/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11125_png_jpg.rf.a631308f89c8f95f7eacece088b8cb15.jpg: 640x640 1 bicycle, 3 cars, 1 motorbike, 11.5ms
# image 69/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11145_png_jpg.rf.5ee060069cb237e7306aa67b00380dfa.jpg: 640x640 1 bicycle, 1 car, 2 motorbikes, 11.6ms
# image 70/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11175_png_jpg.rf.d6e62ee96c0a51a6cb2ccf44d7f7b1fb.jpg: 640x640 1 bicycle, 1 car, 6 motorbikes, 11.6ms
# image 71/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11185_png_jpg.rf.b6d79b3c7bdcf7221dbb59bc7c92f2b8.jpg: 640x640 1 bicycle, 2 cars, 6 motorbikes, 11.5ms
# image 72/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11250_png_jpg.rf.273c60c64c593c73f27252114dc4a19e.jpg: 640x640 2 bicycles, 5 cars, 11.6ms
# image 73/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11315_png_jpg.rf.9899fb650dd98575df30a99882b908b1.jpg: 640x640 2 bicycles, 2 cars, 4 motorbikes, 11.5ms
# image 74/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11410_png_jpg.rf.9b840a5494e2a57a135b6eaf17df1b87.jpg: 640x640 3 bicycles, 4 cars, 1 motorbike, 11.5ms
# image 75/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11425_png_jpg.rf.88e604c56441dff191cf3e94c1e1f778.jpg: 640x640 3 bicycles, 5 cars, 2 motorbikes, 11.5ms
# image 76/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11460_png_jpg.rf.e3569c9ca4f55ad39bdb9f18ae48240f.jpg: 640x640 3 bicycles, 1 car, 4 motorbikes, 11.6ms
# image 77/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11530_png_jpg.rf.e449371b937082607fbbeb4ec09726c2.jpg: 640x640 3 bicycles, 1 car, 6 motorbikes, 1 person, 11.5ms
# image 78/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11580_png_jpg.rf.f64b09fd14e67b556e202cb8efa5a664.jpg: 640x640 1 bicycle, 2 cars, 3 motorbikes, 11.5ms
# image 79/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11615_png_jpg.rf.7eecf3a0f1731a6d4fb499156cac1507.jpg: 640x640 1 bicycle, 2 buss, 4 cars, 2 motorbikes, 11.5ms
# image 80/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11715_png_jpg.rf.9024275e84059155c1915d56b3d1083d.jpg: 640x640 1 bicycle, 4 cars, 11.5ms
# image 81/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11740_png_jpg.rf.4d7c76301215a7b5e8946757a22f6696.jpg: 640x640 1 bicycle, 2 cars, 4 motorbikes, 11.5ms
# image 82/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11820_png_jpg.rf.c1068ad225002e04e2a776cf31ce3fad.jpg: 640x640 1 bicycle, 1 bus, 5 cars, 3 motorbikes, 11.5ms
# image 83/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11855_png_jpg.rf.559a0a288ea195ba25ccd6b66a54ad09.jpg: 640x640 1 bicycle, 3 cars, 2 motorbikes, 11.5ms
# image 84/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11865_png_jpg.rf.9ac57aeec10378242d7b71ec470732a1.jpg: 640x640 1 bicycle, 1 car, 5 motorbikes, 11.5ms
# image 85/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11980_png_jpg.rf.0f28b76ba33f69d4fedae3e71f39d37f.jpg: 640x640 1 bicycle, 3 cars, 11.5ms
# image 86/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-11985_png_jpg.rf.770e7ae0c76d7e946a3b00e086f74a00.jpg: 640x640 2 bicycles, 1 car, 2 motorbikes, 11.5ms
# image 87/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1200_png_jpg.rf.51f0c083d921102dbbf4c46ea7e65a81.jpg: 640x640 2 cars, 4 motorbikes, 11.5ms
# image 88/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12105_png_jpg.rf.ca746f20cdb24209cc407a88d42eb912.jpg: 640x640 1 bicycle, 2 cars, 4 motorbikes, 11.5ms
# image 89/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12120_png_jpg.rf.3a951040438d33746bfafa0721a88e28.jpg: 640x640 1 bicycle, 3 cars, 4 motorbikes, 11.5ms
# image 90/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12140_png_jpg.rf.2e4a2424acb5752b124999b669766e94.jpg: 640x640 1 bicycle, 1 car, 3 motorbikes, 11.5ms
# image 91/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12160_png_jpg.rf.76670361f96a8c1e973633b8df726a5f.jpg: 640x640 1 bicycle, 2 cars, 5 motorbikes, 11.5ms
# image 92/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12175_png_jpg.rf.1505671073fd77dd41176871648069b3.jpg: 640x640 1 bicycle, 3 cars, 5 motorbikes, 11.5ms
# image 93/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12180_png_jpg.rf.54b493e11169f01e34bb18f8aa01b088.jpg: 640x640 2 bicycles, 2 cars, 6 motorbikes, 11.5ms
# image 94/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-12185_png_jpg.rf.bb2d3dfac9d8c571f84ad92229d0adfd.jpg: 640x640 1 bicycle, 2 cars, 7 motorbikes, 11.5ms
# image 95/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1815_png_jpg.rf.577f759aabc16ee8dee6a38e526ef9a1.jpg: 640x640 3 cars, 11.5ms
# image 96/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1815_png_jpg.rf.7743f5a03372d4c0928f0c6f23b0546b.jpg: 640x640 3 cars, 11.5ms
# image 97/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1830_png_jpg.rf.7c8ebaca6675cfaeac73371ffdddb743.jpg: 640x640 3 cars, 11.5ms
# image 98/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1840_png_jpg.rf.fa532123d73379d06cf136371e5f2a70.jpg: 640x640 3 cars, 1 motorbike, 11.5ms
# image 99/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1845_png_jpg.rf.7491020bdbef3f47e8b56c997c169069.jpg: 640x640 2 cars, 4 motorbikes, 11.5ms
# image 100/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-1985_png_jpg.rf.be0e128eed647f3ad17bf908db8455f4.jpg: 640x640 7 motorbikes, 11.5ms
# image 101/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2185_png_jpg.rf.ef9570c136e91a3119c09d600c86a4a3.jpg: 640x640 1 bicycle, 5 cars, 1 motorbike, 11.5ms
# image 102/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2340_png_jpg.rf.731a023f1d84ff655f524db3e9a19eeb.jpg: 640x640 2 cars, 1 motorbike, 1 person, 11.5ms
# image 103/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2355_png_jpg.rf.c0852ed0459970f3609fd92fa941f23d.jpg: 640x640 2 cars, 3 motorbikes, 11.5ms
# image 104/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2455_png_jpg.rf.13e90616bcd9fc3a4966daf780c83da5.jpg: 640x640 3 cars, 4 motorbikes, 1 person, 11.5ms
# image 105/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2490_png_jpg.rf.dde58bf8a1f218286fa1f64b78e7bf1f.jpg: 640x640 2 cars, 3 motorbikes, 11.6ms
# image 106/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2565_png_jpg.rf.c91afd144300c0fd4405f64a82dd80d6.jpg: 640x640 2 cars, 4 motorbikes, 12.0ms
# image 107/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2580_png_jpg.rf.48a22f40df0ad885e0766c0d62b16d3d.jpg: 640x640 5 cars, 2 motorbikes, 11.6ms
# image 108/279 /kaggle/input/traffic-detection-project/test/images/ant_sales-2615_png_jpg.rf.0ceaf2af2a89d4080000f35af44d1b03.jpg: 640x640 1 bicycle, 2 cars, 2 motorbikes, 11.6ms
# image 109/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1035_png_jpg.rf.313fa2718fd690c3fc1c7df404e37dda.jpg: 640x640 6 cars, 7 motorbikes, 11.5ms
# image 110/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1135_png_jpg.rf.1e7c8c12e0a8117c001d65296bfa56e5.jpg: 640x640 10 cars, 11 motorbikes, 11.5ms
# image 111/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1140_png_jpg.rf.548bee19233d1dc5b1d099ce20ac6487.jpg: 640x640 1 bicycle, 11 cars, 6 motorbikes, 11.5ms
# image 112/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-115_png_jpg.rf.275fbdccb6a6ca848ac3cf3ae771946e.jpg: 640x640 1 bus, 10 cars, 10 motorbikes, 11.5ms
# image 113/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-120_png_jpg.rf.537f1ac0f38167cebebe233913726611.jpg: 640x640 1 bus, 8 cars, 6 motorbikes, 11.5ms
# image 114/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1285_png_jpg.rf.837bcc5605e9f4a60a6ce1bf9193747e.jpg: 640x640 6 cars, 4 motorbikes, 11.5ms
# image 115/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1300_png_jpg.rf.bedb30f8d1e8eab461acf70aa4cf9907.jpg: 640x640 2 buss, 6 cars, 5 motorbikes, 11.5ms
# image 116/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1320_png_jpg.rf.737f18e9181c0c7b771a5a7e3eeea929.jpg: 640x640 2 buss, 6 cars, 6 motorbikes, 11.5ms
# image 117/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1320_png_jpg.rf.7ee4622d9617fd8ad21028aa7f63c582.jpg: 640x640 2 buss, 5 cars, 8 motorbikes, 11.5ms
# image 118/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1325_png_jpg.rf.d077c5346d7b9d2b248a589b83978aaf.jpg: 640x640 2 buss, 5 cars, 7 motorbikes, 11.5ms
# image 119/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1410_png_jpg.rf.3c0bc3cdc8804d07543eee7eecc0b8b5.jpg: 640x640 1 bus, 9 cars, 3 motorbikes, 1 person, 11.6ms
# image 120/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1460_png_jpg.rf.6f3adf09f585ad269e88f737da6f9192.jpg: 640x640 2 bicycles, 2 buss, 7 cars, 9 motorbikes, 11.5ms
# image 121/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1480_png_jpg.rf.c7749490281879e2c8b39fd6d2f0101e.jpg: 640x640 2 bicycles, 8 cars, 3 motorbikes, 11.5ms
# image 122/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1555_png_jpg.rf.9ae644ab3412e8169895f8bcc6a9067b.jpg: 640x640 2 bicycles, 1 bus, 11 cars, 12 motorbikes, 11.5ms
# image 123/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1585_png_jpg.rf.bc739a14475d595292a45b72bc970f27.jpg: 640x640 13 cars, 5 motorbikes, 11.6ms
# image 124/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-15_png_jpg.rf.f17f4bfd0b95c95ea830b43031ddd5df.jpg: 640x640 2 buss, 7 cars, 6 motorbikes, 1 person, 11.5ms
# image 125/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1605_png_jpg.rf.9ff453450e848625deb012bce5172451.jpg: 640x640 9 cars, 7 motorbikes, 11.6ms
# image 126/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1610_png_jpg.rf.6a2d1ed46436d18cfd9cfc59dd11b02a.jpg: 640x640 11 cars, 7 motorbikes, 11.5ms
# image 127/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1715_png_jpg.rf.45822792f4f3c060da69def4f8e90f8b.jpg: 640x640 5 cars, 6 motorbikes, 11.5ms
# image 128/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1755_png_jpg.rf.4baca34696f1d0904200d0c58e2344af.jpg: 640x640 3 cars, 1 motorbike, 11.5ms
# image 129/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1870_png_jpg.rf.a5109b9808962afca755b1aeafe17613.jpg: 640x640 1 bicycle, 1 bus, 7 cars, 4 motorbikes, 11.5ms
# image 130/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1880_png_jpg.rf.f341c902790abfe90d3173e36c52408c.jpg: 640x640 1 bus, 7 cars, 10 motorbikes, 11.5ms
# image 131/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-1910_png_jpg.rf.13b8cbe1338d78ba5b13767a834c441c.jpg: 640x640 4 cars, 9 motorbikes, 11.5ms
# image 132/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2020_png_jpg.rf.896528d687c0431a5ba15421ed1d6452.jpg: 640x640 1 bus, 5 cars, 10 motorbikes, 11.5ms
# image 133/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2040_png_jpg.rf.f4897be05a717ba74b5a8728ca1f4591.jpg: 640x640 1 bicycle, 1 bus, 7 cars, 1 motorbike, 11.5ms
# image 134/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2180_png_jpg.rf.98cec5b97edb21562b08cb0f7754bb9c.jpg: 640x640 8 cars, 8 motorbikes, 11.5ms
# image 135/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2205_png_jpg.rf.acf7f960765a466230ae224f259fccfd.jpg: 640x640 6 cars, 4 motorbikes, 11.5ms
# image 136/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2300_png_jpg.rf.f4138ffc186611f0075c32d24129f7de.jpg: 640x640 1 bus, 11 cars, 4 motorbikes, 1 person, 11.6ms
# image 137/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2325_png_jpg.rf.55c9fd8d13614e9acc273d62fca6a991.jpg: 640x640 7 cars, 3 motorbikes, 11.6ms
# image 138/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2335_png_jpg.rf.fa235c9b4bca87050d4a3a4c93585df4.jpg: 640x640 8 cars, 5 motorbikes, 11.5ms
# image 139/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2445_png_jpg.rf.a5b342ba9374a1f4b81fdc8bfb373602.jpg: 640x640 1 bus, 6 cars, 8 motorbikes, 11.5ms
# image 140/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2455_png_jpg.rf.9c781508aa471f79d9571df5df404b19.jpg: 640x640 5 cars, 11 motorbikes, 11.5ms
# image 141/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2610_png_jpg.rf.bd729eb3e7cd3cc6c069a9e66e838504.jpg: 640x640 1 bicycle, 1 bus, 7 cars, 3 motorbikes, 11.5ms
# image 142/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2615_png_jpg.rf.849d17c3fd8df1642cab39074aec90ab.jpg: 640x640 1 bicycle, 1 bus, 6 cars, 1 motorbike, 11.6ms
# image 143/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2630_png_jpg.rf.79564bce05f3be8799a632e56cf1be41.jpg: 640x640 7 cars, 3 motorbikes, 11.5ms
# image 144/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-2760_png_jpg.rf.0a91eb87ee2021d9ab7a8c995e77e4e6.jpg: 640x640 4 cars, 6 motorbikes, 1 person, 11.5ms
# image 145/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-405_png_jpg.rf.cdb0860def4d0b3a15ecc51682271f22.jpg: 640x640 1 bus, 16 cars, 7 motorbikes, 11.5ms
# image 146/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-45_png_jpg.rf.997aa3902d2810cec0ed0da3b6fdb4e0.jpg: 640x640 5 cars, 4 motorbikes, 11.5ms
# image 147/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-555_png_jpg.rf.43cdcffa729c48465570809ffffa3af8.jpg: 640x640 1 bus, 5 cars, 6 motorbikes, 11.5ms
# image 148/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-620_png_jpg.rf.3c794894a576d0d6355379613c2dadc5.jpg: 640x640 6 cars, 8 motorbikes, 11.5ms
# image 149/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-695_png_jpg.rf.848ef761062610a83c80e17d7ec549fd.jpg: 640x640 9 cars, 7 motorbikes, 11.5ms
# image 150/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-750_png_jpg.rf.1ecfffea74b809e9d3a86ac4d9eb562c.jpg: 640x640 1 bus, 4 cars, 4 motorbikes, 11.5ms
# image 151/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-760_png_jpg.rf.87a86a72f6e8c3d07f4aea59e5ccfe30.jpg: 640x640 1 bus, 5 cars, 2 motorbikes, 11.6ms
# image 152/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-900_png_jpg.rf.4e6ca105e001b7af18209503f66e7a7f.jpg: 640x640 4 cars, 3 motorbikes, 11.5ms
# image 153/279 /kaggle/input/traffic-detection-project/test/images/duque_de_caxias-995_png_jpg.rf.8eb6ae806d383a68998e792fa8941d34.jpg: 640x640 1 bicycle, 5 cars, 1 motorbike, 11.5ms
# image 154/279 /kaggle/input/traffic-detection-project/test/images/image01_png_jpg.rf.439f3323af6b81619c993de762d69825.jpg: 640x640 1 bicycle, 8 cars, 1 motorbike, 18 persons, 11.6ms
# image 155/279 /kaggle/input/traffic-detection-project/test/images/image07_png_jpg.rf.337fd5d7f0c03747972168aeb8f286a9.jpg: 640x640 22 cars, 4 persons, 11.5ms
# image 156/279 /kaggle/input/traffic-detection-project/test/images/image08_png_jpg.rf.3fa58230a35fb3e0d9abb94959090942.jpg: 640x640 24 cars, 2 persons, 11.5ms
# image 157/279 /kaggle/input/traffic-detection-project/test/images/image11_png_jpg.rf.fc3552ed0b2472b3cf27532253bcb974.jpg: 640x640 39 cars, 5 persons, 11.5ms
# image 158/279 /kaggle/input/traffic-detection-project/test/images/image19_png_jpg.rf.198d9940a9c989685302cc7ef957f20f.jpg: 640x640 1 bus, 21 cars, 11.5ms
# image 159/279 /kaggle/input/traffic-detection-project/test/images/image21_png_jpg.rf.83406cc09d38698bf7073e1e379fdd7d.jpg: 640x640 1 bicycle, 7 cars, 20 persons, 11.6ms
# image 160/279 /kaggle/input/traffic-detection-project/test/images/image21_png_jpg.rf.cbee504d940e761db6ac355d7e75459e.jpg: 640x640 1 bicycle, 1 bus, 8 cars, 22 persons, 11.6ms
# image 161/279 /kaggle/input/traffic-detection-project/test/images/image30_png_jpg.rf.c459ecd0d8922c9379bfc699052182d8.jpg: 640x640 1 bicycle, 7 cars, 15 persons, 11.5ms
# image 162/279 /kaggle/input/traffic-detection-project/test/images/image31_png_jpg.rf.7c4a897e56fe5bd795568e4f936e3d0d.jpg: 640x640 2 bicycles, 7 cars, 18 persons, 11.6ms
# image 163/279 /kaggle/input/traffic-detection-project/test/images/image35_png_jpg.rf.1fa3af77bef2187945da485e099b22bd.jpg: 640x640 2 bicycles, 10 cars, 5 persons, 11.5ms
# image 164/279 /kaggle/input/traffic-detection-project/test/images/image41_png_jpg.rf.0491e6f32304a84ab6c549ba311b268a.jpg: 640x640 1 bicycle, 22 cars, 7 persons, 11.5ms
# image 165/279 /kaggle/input/traffic-detection-project/test/images/image44_png_jpg.rf.2123dd144606f16b090ccf6c7d4640bf.jpg: 640x640 2 bicycles, 9 cars, 1 motorbike, 7 persons, 11.5ms
# image 166/279 /kaggle/input/traffic-detection-project/test/images/image47_png_jpg.rf.75720d667f1a1ad75ff23f31a5e6436b.jpg: 640x640 1 bicycle, 8 cars, 9 persons, 11.5ms
# image 167/279 /kaggle/input/traffic-detection-project/test/images/image50_png_jpg.rf.a8cef7c79d333922adadc38fd7b8134a.jpg: 640x640 1 bicycle, 1 bus, 9 cars, 15 persons, 11.5ms
# image 168/279 /kaggle/input/traffic-detection-project/test/images/image53_png_jpg.rf.013caaefa4713cb091ea92ff73c0ae67.jpg: 640x640 17 cars, 4 persons, 11.5ms
# image 169/279 /kaggle/input/traffic-detection-project/test/images/image55_png_jpg.rf.c59a99ec27127c39452f1ea66e7d61c5.jpg: 640x640 6 cars, 11.5ms
# image 170/279 /kaggle/input/traffic-detection-project/test/images/image58_png_jpg.rf.80285cd4d710d83c7d5c2e6d1374a52e.jpg: 640x640 5 persons, 11.5ms
# image 171/279 /kaggle/input/traffic-detection-project/test/images/image59_png_jpg.rf.b289a860a3c4cd29addc6a76ac5287b3.jpg: 640x640 1 bicycle, 3 cars, 9 persons, 11.5ms
# image 172/279 /kaggle/input/traffic-detection-project/test/images/image62_png_jpg.rf.2b09194ea60415a31dd2323079bdf880.jpg: 640x640 1 bicycle, 13 persons, 11.5ms
# image 173/279 /kaggle/input/traffic-detection-project/test/images/image62_png_jpg.rf.6898b7d417bb9a3e7cf40f36f75c938d.jpg: 640x640 1 bicycle, 11 persons, 11.5ms
# image 174/279 /kaggle/input/traffic-detection-project/test/images/image63_png_jpg.rf.20446a41b261c4064c9dd960e1a5b444.jpg: 640x640 1 car, 3 persons, 11.5ms
# image 175/279 /kaggle/input/traffic-detection-project/test/images/image64_png_jpg.rf.d6a51ccd625b5b83f02af040108aa0bb.jpg: 640x640 5 persons, 11.5ms
# image 176/279 /kaggle/input/traffic-detection-project/test/images/image65_png_jpg.rf.4b59ec23626f2dc537b33c0e021070f3.jpg: 640x640 2 bicycles, 1 car, 6 persons, 11.5ms
# image 177/279 /kaggle/input/traffic-detection-project/test/images/image67_png_jpg.rf.88792b888a7edd6137de201bc8f75cd7.jpg: 640x640 1 bicycle, 2 cars, 9 persons, 11.6ms
# image 178/279 /kaggle/input/traffic-detection-project/test/images/image67_png_jpg.rf.fa5d34c89cd6ec63e65c786ad2bc65fd.jpg: 640x640 1 bicycle, 3 cars, 9 persons, 11.5ms
# image 179/279 /kaggle/input/traffic-detection-project/test/images/image68_png_jpg.rf.44e19a08eb08ad8b35863b46f74a4a30.jpg: 640x640 1 car, 1 person, 11.5ms
# image 180/279 /kaggle/input/traffic-detection-project/test/images/image69_png_jpg.rf.adcccb5a86aabbab3302f249ae58ab59.jpg: 640x640 3 persons, 11.6ms
# image 181/279 /kaggle/input/traffic-detection-project/test/images/image73_png_jpg.rf.542459ff113f00fcc89c0e0b150b411e.jpg: 640x640 1 bicycle, 2 cars, 1 person, 11.5ms
# image 182/279 /kaggle/input/traffic-detection-project/test/images/image74_png_jpg.rf.a14c133aa13eb2152dd54e16dbbb0112.jpg: 640x640 1 bicycle, 2 cars, 1 person, 11.5ms
# image 183/279 /kaggle/input/traffic-detection-project/test/images/image76_png_jpg.rf.ab816fbddf112f3f5dccd0b0d8e5a6cb.jpg: 640x640 2 persons, 11.6ms
# image 184/279 /kaggle/input/traffic-detection-project/test/images/image78_png_jpg.rf.2ad49f5044234f42068aca3f6d0cdfb3.jpg: 640x640 1 bicycle, 5 cars, 2 persons, 11.6ms
# image 185/279 /kaggle/input/traffic-detection-project/test/images/image78_png_jpg.rf.f2fb0b7e3afba581e4c44b8a38708b29.jpg: 640x640 1 bicycle, 5 cars, 2 persons, 11.5ms
# image 186/279 /kaggle/input/traffic-detection-project/test/images/image79_png_jpg.rf.0a0da7876cf851c2478f518fcaba76cb.jpg: 640x640 1 bicycle, 6 cars, 1 person, 11.5ms
# image 187/279 /kaggle/input/traffic-detection-project/test/images/image80_png_jpg.rf.34a09efa2db16fc828cdbe311bcbf330.jpg: 640x640 1 bicycle, 5 cars, 1 motorbike, 4 persons, 11.6ms
# image 188/279 /kaggle/input/traffic-detection-project/test/images/image81_png_jpg.rf.0212cbe07936d30a8b71457ceeab9033.jpg: 640x640 2 bicycles, 6 cars, 1 motorbike, 2 persons, 11.5ms
# image 189/279 /kaggle/input/traffic-detection-project/test/images/image81_png_jpg.rf.30fe001de9837685fe47172bb2f705e4.jpg: 640x640 2 bicycles, 6 cars, 1 motorbike, 2 persons, 11.6ms
# image 190/279 /kaggle/input/traffic-detection-project/test/images/image82_png_jpg.rf.d619a17465c637d145a9a364613f2d11.jpg: 640x640 2 cars, 2 persons, 11.8ms
# image 191/279 /kaggle/input/traffic-detection-project/test/images/image85_png_jpg.rf.f550e45639ed70b446ed3463f2add9bc.jpg: 640x640 2 cars, 7 persons, 11.6ms
# image 192/279 /kaggle/input/traffic-detection-project/test/images/image91_png_jpg.rf.10844b97253f7b4aee90dbd7e3bf6b3a.jpg: 640x640 1 bicycle, 2 cars, 7 persons, 11.5ms
# image 193/279 /kaggle/input/traffic-detection-project/test/images/image92_png_jpg.rf.9dc255607ab316d0a1be7d7d244ef073.jpg: 640x640 2 cars, 8 persons, 11.5ms
# image 194/279 /kaggle/input/traffic-detection-project/test/images/image92_png_jpg.rf.cc125f2b0f4144d505ad18fb175de063.jpg: 640x640 2 cars, 10 persons, 11.5ms
# image 195/279 /kaggle/input/traffic-detection-project/test/images/image92_png_jpg.rf.f63d6d7fe05abc81ca91184d2507cd9d.jpg: 640x640 2 cars, 7 persons, 11.5ms
# image 196/279 /kaggle/input/traffic-detection-project/test/images/image93_png_jpg.rf.db0e6e038d0f47fd708e5aca86dc3457.jpg: 640x640 6 cars, 11.5ms
# image 197/279 /kaggle/input/traffic-detection-project/test/images/image96_png_jpg.rf.f07b64a94f8e0128ed6fa0004b7ef371.jpg: 640x640 1 bicycle, 5 cars, 2 persons, 11.5ms
# image 198/279 /kaggle/input/traffic-detection-project/test/images/screenshot_0_jpg.rf.ecd6411b3a4ad4840d868affd0b6b2f7.jpg: 640x640 6 cars, 11.5ms
# image 199/279 /kaggle/input/traffic-detection-project/test/images/screenshot_10136_jpg.rf.95227b3b5cecb4bfda99f05fe5ea1567.jpg: 640x640 1 bicycle, 5 cars, 11.5ms
# image 200/279 /kaggle/input/traffic-detection-project/test/images/screenshot_10434_jpg.rf.f883516c2fe87b81610b5b72603c4c78.jpg: 640x640 9 cars, 11.5ms
# image 201/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11030_jpg.rf.74c2874cac4916f2e472aeb6437bd2ec.jpg: 640x640 6 cars, 11.5ms
# image 202/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11194_jpg.rf.52e0c38f16273a1db4d5b6ccb3983ac1.jpg: 640x640 1 bus, 25 cars, 2 persons, 11.5ms
# image 203/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11477_jpg.rf.9c867e02d062db81491d8be979bd56eb.jpg: 640x640 5 cars, 11.5ms
# image 204/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11626_jpg.rf.3b9c72b920b6c1ed282e261dc40e2d31.jpg: 640x640 5 cars, 11.5ms
# image 205/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11790_jpg.rf.be1e04fb2f3e951c5d81d27325fddf41.jpg: 640x640 26 cars, 1 motorbike, 3 persons, 11.5ms
# image 206/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11925_jpg.rf.f809b665f8b4efe6469423a4629592eb.jpg: 640x640 3 cars, 1 person, 11.5ms
# image 207/279 /kaggle/input/traffic-detection-project/test/images/screenshot_11939_jpg.rf.dbdf84b072a4be686e552190a5eccdab.jpg: 640x640 18 cars, 2 persons, 11.5ms
# image 208/279 /kaggle/input/traffic-detection-project/test/images/screenshot_12223_jpg.rf.2eef1aa7144235c2f933c29f40e0a7ec.jpg: 640x640 5 cars, 11.5ms
# image 209/279 /kaggle/input/traffic-detection-project/test/images/screenshot_12375_jpg.rf.03633468ccad246949a95e834ef213cf.jpg: 640x640 2 cars, 1 person, 11.5ms
# image 210/279 /kaggle/input/traffic-detection-project/test/images/screenshot_12524_jpg.rf.a0007d904098f23ee626c345105ebd30.jpg: 640x640 1 car, 11.5ms
# image 211/279 /kaggle/input/traffic-detection-project/test/images/screenshot_12673_jpg.rf.e8f3e418b0bc9c359b0c9064bb2e8383.jpg: 640x640 4 persons, 11.5ms
# image 212/279 /kaggle/input/traffic-detection-project/test/images/screenshot_12684_jpg.rf.dd8d4ebfc76f293ed365bb5c2594574c.jpg: 640x640 12 cars, 1 motorbike, 6 persons, 11.6ms
# image 213/279 /kaggle/input/traffic-detection-project/test/images/screenshot_13120_jpg.rf.5f1b7814aa402d7e03a005b955eaae10.jpg: 640x640 1 car, 2 persons, 11.5ms
# image 214/279 /kaggle/input/traffic-detection-project/test/images/screenshot_14324_jpg.rf.e0e997784af6427e20d0136c75ff1b5a.jpg: 640x640 10 cars, 15 persons, 11.5ms
# image 215/279 /kaggle/input/traffic-detection-project/test/images/screenshot_14906_jpg.rf.a9e8b666fa95292d6bab6c8d39fc5c2e.jpg: 640x640 (no detections), 11.5ms
# image 216/279 /kaggle/input/traffic-detection-project/test/images/screenshot_149_jpg.rf.bde136cf5d0bc398d6dd9569a5826b34.jpg: 640x640 6 cars, 11.6ms
# image 217/279 /kaggle/input/traffic-detection-project/test/images/screenshot_15205_jpg.rf.b0f42755e701d07bf4e5cc3b17d62379.jpg: 640x640 2 cars, 2 persons, 11.6ms
# image 218/279 /kaggle/input/traffic-detection-project/test/images/screenshot_15815_jpg.rf.509aca1dc01d351507b4600bf967a847.jpg: 640x640 6 cars, 11.5ms
# image 219/279 /kaggle/input/traffic-detection-project/test/images/screenshot_15950_jpg.rf.464c86e7816fe125ea137a3c01f55a87.jpg: 640x640 4 cars, 11.5ms
# image 220/279 /kaggle/input/traffic-detection-project/test/images/screenshot_1639_jpg.rf.0a09ac7a5b8a784e06bb4cfac7528893.jpg: 640x640 1 car, 11.5ms
# image 221/279 /kaggle/input/traffic-detection-project/test/images/screenshot_1639_jpg.rf.c81c55b50182804ce1aae0d254881e42.jpg: 640x640 19 cars, 7 persons, 11.5ms
# image 222/279 /kaggle/input/traffic-detection-project/test/images/screenshot_16709_jpg.rf.e5f7f17be1b8324a08bfd8575cc9efaf.jpg: 640x640 4 cars, 2 motorbikes, 11.6ms
# image 223/279 /kaggle/input/traffic-detection-project/test/images/screenshot_16845_jpg.rf.540c7a18ae7d15b4255b103331501bed.jpg: 640x640 (no detections), 11.5ms
# image 224/279 /kaggle/input/traffic-detection-project/test/images/screenshot_16994_jpg.rf.0c39b77976b205ce5567c56bb6139200.jpg: 640x640 1 car, 1 person, 11.5ms
# image 225/279 /kaggle/input/traffic-detection-project/test/images/screenshot_17887_jpg.rf.6487401d8009a02fee435141de4ba4b6.jpg: 640x640 1 car, 11.5ms
# image 226/279 /kaggle/input/traffic-detection-project/test/images/screenshot_1790_jpg.rf.c5aa52e7f13464df9f29993d6bc54d1d.jpg: 640x640 11 cars, 11.5ms
# image 227/279 /kaggle/input/traffic-detection-project/test/images/screenshot_18497_jpg.rf.e3ef7034823309e4379b419048f640bf.jpg: 640x640 5 cars, 1 person, 11.6ms
# image 228/279 /kaggle/input/traffic-detection-project/test/images/screenshot_1937_jpg.rf.a981f367a83eb3c71b02126b51f6c853.jpg: 640x640 2 cars, 11.5ms
# image 229/279 /kaggle/input/traffic-detection-project/test/images/screenshot_1942_jpg.rf.a416586c75ccc39c69c4cfb481a696e6.jpg: 640x640 2 cars, 11.5ms
# image 230/279 /kaggle/input/traffic-detection-project/test/images/screenshot_2387_jpg.rf.517318df5376a53bc68c10be6ffce628.jpg: 640x640 7 cars, 5 persons, 11.5ms
# image 231/279 /kaggle/input/traffic-detection-project/test/images/screenshot_25341_jpg.rf.b6353b362a87027fb12315ae60a67221.jpg: 640x640 (no detections), 11.5ms
# image 232/279 /kaggle/input/traffic-detection-project/test/images/screenshot_2535_jpg.rf.43c98bc5595382088071ec1f10445faf.jpg: 640x640 5 cars, 1 person, 11.6ms
# image 233/279 /kaggle/input/traffic-detection-project/test/images/screenshot_25490_jpg.rf.b3bc4380f62f8aea24376213c9d5589b.jpg: 640x640 1 car, 1 person, 11.5ms
# image 234/279 /kaggle/input/traffic-detection-project/test/images/screenshot_26384_jpg.rf.1c044283afc0cc53a66c0658151bc146.jpg: 640x640 3 cars, 2 persons, 11.5ms
# image 235/279 /kaggle/input/traffic-detection-project/test/images/screenshot_26533_jpg.rf.4f20415f4d181828961118dda8c82a1b.jpg: 640x640 1 bus, 5 cars, 4 persons, 11.6ms
# image 236/279 /kaggle/input/traffic-detection-project/test/images/screenshot_27129_jpg.rf.c67a199f07c98e2e2183870698472a3b.jpg: 640x640 2 buss, 3 cars, 1 person, 11.6ms
# image 237/279 /kaggle/input/traffic-detection-project/test/images/screenshot_2831_jpg.rf.c83e3b9638e5a2b6c3c7e88829e8c092.jpg: 640x640 22 cars, 1 motorbike, 11 persons, 11.5ms
# image 238/279 /kaggle/input/traffic-detection-project/test/images/screenshot_2831_jpg.rf.efa61419402d68fdd223bf84c7140fe1.jpg: 640x640 8 cars, 11.5ms
# image 239/279 /kaggle/input/traffic-detection-project/test/images/screenshot_29364_jpg.rf.8405af54021956e21c6370a2dc84cf5b.jpg: 640x640 1 car, 11.5ms
# image 240/279 /kaggle/input/traffic-detection-project/test/images/screenshot_2980_jpg.rf.3525299450c887d279660ba78017d0b3.jpg: 640x640 23 cars, 1 motorbike, 10 persons, 11.5ms
# image 241/279 /kaggle/input/traffic-detection-project/test/images/screenshot_29811_jpg.rf.437232d7f824cf21338405e5a5b4284b.jpg: 640x640 2 persons, 11.5ms
# image 242/279 /kaggle/input/traffic-detection-project/test/images/screenshot_300_jpg.rf.4318af4c31fc81d9dfd8501bed1cb2b3.jpg: 640x640 7 cars, 2 persons, 11.6ms
# image 243/279 /kaggle/input/traffic-detection-project/test/images/screenshot_32345_jpg.rf.a43fa3a66e3924c50fc4c38a22b0a04e.jpg: 640x640 13 cars, 11.5ms
# image 244/279 /kaggle/input/traffic-detection-project/test/images/screenshot_33984_jpg.rf.d9e792ea15202d4adf7168aa5048b3ac.jpg: 640x640 2 cars, 11.5ms
# image 245/279 /kaggle/input/traffic-detection-project/test/images/screenshot_3427_jpg.rf.e1a4fdeb16c3dc963e9a71ff9e3c7bb5.jpg: 640x640 2 cars, 11.5ms
# image 246/279 /kaggle/input/traffic-detection-project/test/images/screenshot_3429_jpg.rf.1f0fddd36ee7c6caecb42bd25b9b9087.jpg: 640x640 4 cars, 11.5ms
# image 247/279 /kaggle/input/traffic-detection-project/test/images/screenshot_34431_jpg.rf.de41bc1b90f2c4308de6b007dbcbda39.jpg: 640x640 9 cars, 11.5ms
# image 248/279 /kaggle/input/traffic-detection-project/test/images/screenshot_3576_jpg.rf.5b6d5dfe5490b5c85191ab42b0239e16.jpg: 640x640 1 bicycle, 30 cars, 4 persons, 11.5ms
# image 249/279 /kaggle/input/traffic-detection-project/test/images/screenshot_3576_jpg.rf.677ee49aacd9da749aeba086b5506f71.jpg: 640x640 1 bicycle, 31 cars, 5 persons, 11.5ms
# image 250/279 /kaggle/input/traffic-detection-project/test/images/screenshot_36369_jpg.rf.6ef56409df9f8d5ce61903b230a84fce.jpg: 640x640 5 cars, 11.6ms
# image 251/279 /kaggle/input/traffic-detection-project/test/images/screenshot_36518_jpg.rf.0518486725746279ff2eb223ac6fbb5c.jpg: 640x640 4 cars, 11.5ms
# image 252/279 /kaggle/input/traffic-detection-project/test/images/screenshot_37264_jpg.rf.cfc1f6f34392575718f8e7a99c633b64.jpg: 640x640 6 persons, 11.5ms
# image 253/279 /kaggle/input/traffic-detection-project/test/images/screenshot_38159_jpg.rf.1ed1c7b8245c077884b38e6dc316ddd9.jpg: 640x640 5 cars, 11.5ms
# image 254/279 /kaggle/input/traffic-detection-project/test/images/screenshot_4023_jpg.rf.f804c4c2311f7d06401bf123c0f07fb8.jpg: 640x640 1 bus, 17 cars, 10 persons, 11.5ms
# image 255/279 /kaggle/input/traffic-detection-project/test/images/screenshot_4172_jpg.rf.ef42a95150aae8de72428d54e1b7a871.jpg: 640x640 1 bicycle, 1 bus, 18 cars, 7 persons, 11.5ms
# image 256/279 /kaggle/input/traffic-detection-project/test/images/screenshot_447_jpg.rf.104e53fba749790e15549ee781b2fe03.jpg: 640x640 27 cars, 9 persons, 11.5ms
# image 257/279 /kaggle/input/traffic-detection-project/test/images/screenshot_450_jpg.rf.661aa35ea660b7598f9b6ea7c26c93bc.jpg: 640x640 12 cars, 3 persons, 11.6ms
# image 258/279 /kaggle/input/traffic-detection-project/test/images/screenshot_4_jpg.rf.b1e6c1e8514177ac3b72352841fe7532.jpg: 640x640 6 cars, 11.6ms
# image 259/279 /kaggle/input/traffic-detection-project/test/images/screenshot_5365_jpg.rf.4ffc3de5ea67649067497f222107d961.jpg: 640x640 4 cars, 11.5ms
# image 260/279 /kaggle/input/traffic-detection-project/test/images/screenshot_5365_jpg.rf.adde255fa4fb10198205d0f1d1f01f2a.jpg: 640x640 3 cars, 11.5ms
# image 261/279 /kaggle/input/traffic-detection-project/test/images/screenshot_5366_jpg.rf.437880e69614f734fe9dd4a0c2c55d58.jpg: 640x640 5 cars, 11.5ms
# image 262/279 /kaggle/input/traffic-detection-project/test/images/screenshot_5680_jpg.rf.b54614fe8ef57824f07aea1f25294871.jpg: 640x640 1 bicycle, 11 cars, 1 motorbike, 8 persons, 11.5ms
# image 263/279 /kaggle/input/traffic-detection-project/test/images/screenshot_5813_jpg.rf.e13418cf6416d2d2dce66fd1c35c579c.jpg: 640x640 5 cars, 11.5ms
# image 264/279 /kaggle/input/traffic-detection-project/test/images/screenshot_596_jpg.rf.c02e5c14499c9eb220d340a21f3527c5.jpg: 640x640 29 cars, 5 persons, 11.5ms
# image 265/279 /kaggle/input/traffic-detection-project/test/images/screenshot_598_jpg.rf.0e9299d9c105fbe5444a9f124824a128.jpg: 640x640 1 bus, 28 cars, 9 persons, 11.6ms
# image 266/279 /kaggle/input/traffic-detection-project/test/images/screenshot_7155_jpg.rf.35a027ef26421ff747863a5d883c3083.jpg: 640x640 3 cars, 1 person, 11.5ms
# image 267/279 /kaggle/input/traffic-detection-project/test/images/screenshot_745_jpg.rf.77a672ae80a282bd5fd813747dfcf370.jpg: 640x640 28 cars, 13 persons, 11.6ms
# image 268/279 /kaggle/input/traffic-detection-project/test/images/screenshot_7751_jpg.rf.8e647483ab4a7f4882b52958407048f6.jpg: 640x640 3 cars, 11.5ms
# image 269/279 /kaggle/input/traffic-detection-project/test/images/screenshot_7754_jpg.rf.311dc7be2777e7fccdd513ebf2a29738.jpg: 640x640 1 bus, 2 cars, 1 person, 11.5ms
# image 270/279 /kaggle/input/traffic-detection-project/test/images/screenshot_7766_jpg.rf.8b430f24fd50a1e629a2caf757e0af82.jpg: 640x640 1 bicycle, 10 cars, 5 persons, 11.5ms
# image 271/279 /kaggle/input/traffic-detection-project/test/images/screenshot_8201_jpg.rf.4884eb4613cbeac757f6c16e2c6989c5.jpg: 640x640 3 cars, 11.6ms
# image 272/279 /kaggle/input/traffic-detection-project/test/images/screenshot_8496_jpg.rf.1ce57a07fd67e9bc7e884d184f9b55d9.jpg: 640x640 1 car, 11.5ms
# image 273/279 /kaggle/input/traffic-detection-project/test/images/screenshot_8496_jpg.rf.cac958b65223d70b78142091b9721f1a.jpg: 640x640 1 car, 1 person, 11.6ms
# image 274/279 /kaggle/input/traffic-detection-project/test/images/screenshot_8794_jpg.rf.c0ca9bf8cda99d02bb34f33ee13d6d4b.jpg: 640x640 (no detections), 11.5ms
# image 275/279 /kaggle/input/traffic-detection-project/test/images/screenshot_9093_jpg.rf.1d2f799b5a57217ceda298f977e4cfc7.jpg: 640x640 5 cars, 11.6ms
# image 276/279 /kaggle/input/traffic-detection-project/test/images/screenshot_9242_jpg.rf.ded3309a7def92abf88b3e4c9cede1d1.jpg: 640x640 4 cars, 11.6ms
# image 277/279 /kaggle/input/traffic-detection-project/test/images/screenshot_9391_jpg.rf.33421dd12ddbab55c2ae43b722415b4a.jpg: 640x640 5 cars, 11.5ms
# image 278/279 /kaggle/input/traffic-detection-project/test/images/screenshot_9554_jpg.rf.bb12385e91addae9bab7322ce72488e7.jpg: 640x640 2 bicycles, 27 cars, 1 motorbike, 7 persons, 11.5ms
# image 279/279 /kaggle/input/traffic-detection-project/test/images/screenshot_9852_jpg.rf.92779155609ca55851c9fe6a19631577.jpg: 640x640 26 cars, 1 motorbike, 4 persons, 11.6ms
# Speed: 0.5ms pre-process, 11.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage2

# %%
color_dict = {
    'bicycle': (0, 255, 0),  # màu xanh lá cây
    'bus': (0, 0, 255),      # màu xanh dương
    'car': (255, 0, 0),      # màu đỏ
    'motorbike': (255, 255, 0), # màu vàng
    'person': (0, 255, 255)  # màu xanh lục
}

# %%
# !ls /kaggle/working/yolov5/runs/detect/expTestImage

# %%
from PIL import Image
from glob import glob
all_path = glob("/kaggle/working/yolov5/runs/detect/expTestImage2/*")
Image.open(all_path[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# !pip3 install onnx>=1.10.0

# %%
input_width = 448 
input_height = 448 

# !python3 export.py --weights runs/train/yolov5s_results/weights/best.pt --img {input_height} {input_width} --batch 1 --include "onnx" --simplify
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/yolov5s_results/weights/best.pt'], imgsz=[448, 448], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.0 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/yolov5s_results/weights/best.pt with output shape (1, 12348, 10) (13.7 MB)
#
# ONNX: starting export with onnx 1.14.1...
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnx-simplifier 0.4.33...
# ONNX: export success ✅ 2.0s, saved as runs/train/yolov5s_results/weights/best.onnx (27.0 MB)
#
# Export complete (2.6s)
# Results saved to /kaggle/working/yolov5/runs/train/yolov5s_results/weights
# Detect:          python detect.py --weights runs/train/yolov5s_results/weights/best.onnx
# Validate:        python val.py --weights runs/train/yolov5s_results/weights/best.onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'runs/train/yolov5s_results/weights/best.onnx')
# Visualize:       https://netron.app

# %%
1
# Out:
# 1
